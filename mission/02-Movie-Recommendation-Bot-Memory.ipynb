# %%
import openai

client = openai.OpenAI()
messages = []

SYSTEM_PROMPT="""
너는 영화 추천 봇이야.
사용자가 좋아하는 장르와 이미 시청한 영화를 기억해.
대화 기록을 기반으로 개인화된 추천 제공을 해줘.
내가 이미 보았던 영화는 추천하지 말아줘.
"""
messages.append({"role":"system","content":SYSTEM_PROMPT})

def call_ai():
    response = client.chat.completions.create(
        model = "gpt-4o-mini",
        messages = messages
    )
    message = response.choices[0].message.content
    messages.append({"role":"assistant","content":message})
    print(f"AI: {message}")

while True:
    message = input("Send a message to the LLM ...")

    if message == "quit" or message == "q":
        break
    else:
        messages.append({"role":"user","content":message})
        print(f"User: {message}")
        call_ai()
        print("="*100)
# Out:
# User: 나는 SF 영화를 좋아해
# AI: SF 장르를 좋아하시는군요! 이전에 어떤 SF 영화를 보셨는지 말씀해 주실 수 있을까요? 그러면 그에 맞춰서 추천해 드릴 수 있습니다.
# ====================================================================================================
# User: 인셉션이랑 인터스텔라는 이미 봤어
# AI: 좋습니다! "인셉션"과 "인터스텔라"를 보셨군요. 그 두 영화와 비슷한 느낌의 SF 영화를 추천해 드릴게요.
#
# 1. **메멘토 (Memento)** - 기억 상실증을 가진 주인공이 자신의 아내를 죽인 범인을 추적하는 이야기로, 복잡한 서사 구조가 인상적입니다.
# 2. **테넷 (Tenet)** - 시간의 순서를 반전시키는 독특한 설정의 영화로, 크리스토퍼 놀란 감독의 작품입니다.
# 3. **엑스 마키나 (Ex Machina)** - 인공지능과 인간의 관계를 탐구하는 심리 스릴러입니다.
#
# 이 외에 더 궁금한 영화가 있다면 말씀해 주세요!
# ====================================================================================================
# User: 오늘 밤에 뭐 볼지 추천해 줄래?
# AI: 물론입니다! 오늘 밤에 볼 만한 SF 영화로는 다음과 같은 작품들을 추천드립니다:
#
# 1. **소스 코드 (Source Code)** - 한 남자가 암살 사건을 해결하기 위해 과거의 시간으로 돌아가는 독특한 이야기입니다. 긴장감과 반전이 돋보입니다.
#
# 2. **Arrival (Arrival)** - 외계인과의 첫 접촉을 다룬 영화로, 언어와 의사소통의 중요성을 탐구합니다. 감정적인 깊이가 있는 작품입니다.
#
# 3. **Blade Runner 2049** - 1982년 영화 "블레이드 러너"의 후속편으로, 인공지능과 인간의 경계를 탐구하는 멋진 비주얼과 스토리를 자랑합니다.
#
# 오늘 밤에 어떤 영화가 마음에 드시나요?
# ====================================================================================================
# User: 내가 좋아하는 장르랑 이미 본 영화가 뭐라고 했지?
# AI: 당신은 SF 장르를 좋아하시고, 이미 "인셉션"과 "인터스텔라"를 보셨다고 하셨습니다. 이 정보를 바탕으로 추천해 드렸습니다! 추가로 보고 싶은 영화가 있으신가요? 다른 장르의 추천도 가능합니다!
# ====================================================================================================
